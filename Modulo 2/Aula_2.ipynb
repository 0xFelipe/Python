# %% [markdown]
# <a href="https://colab.research.google.com/github/0xFelipe/Python/blob/main/Modulo%202/Aula_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pdfplumber

# %%
# importando os pacotes necessários
import pdfplumber
import os
from google.colab import drive

# %%
# montar o drive
drive.mount ("/content/gdrive")
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# Verificar diretorio atual
os.getcwd()
# Out:
# '/content'

# %%
#lista de arquivos no diretorio
os.listdir()
# Out:
# ['Aula 2.ipynb',
#  'Primeiro_Arquivo.txt',
#  'Segundo_Arquivo.txt',
#  'Aula 1.ipynb',
#  'modelo_de_relatorio.pdf',
#  '.ipynb_checkpoints']

# %%
# Navegador por diretorio
os.chdir("/content/gdrive/MyDrive/Colab Notebooks/Modulo 2")

# %%
# Importando documento PDF com o pdfplumber
pdf = pdfplumber.open ("/content/gdrive/MyDrive/Colab Notebooks/Modulo 2/modelo_de_relatorio.pdf")

# %%
# Verificando quantidade de paginas
pdf.pages
# Out:
# [<Page:1>, <Page:2>, <Page:3>]

# %%
# Acessando as paginas entre [] escreva o numero da pagina onde 0 sempre sera a 1ª
pdf.pages [0]
# Out:
# <Page:1>

# %%
# Selecionando pagina
page1 = pdf.pages [0]
page1
# Out:
# <Page:1>

# %%
# Extrair texto do arquivo PDF
page1.extract_text()
# Out:
# 'SIGMOIDAL \n   \nRelatório Diário \n \nData: 10/08/2020 \n \nRECEITA: R$ 1.397,00 \nDADOS ATUALIZADOS POR CARLOS MELO\n \n \n Visitantes: 1367 \nA quantidade de visitantes diz respeito a visitantes únicos visitando qualquer \npágina do domínio ou subdomínio sigmoidal.ai. Compreende, então, cursos, \nblogs e landing pages. \n Inscritos: 33 \nÉ considerado aqui o número de leads gerados por meio de cadastro \nvoluntário nos formulários do cabeçalho, rodapé ou materiais ricos (como \neBook, infográficos, entre outros). \n Assinantes: 6 \nClientes assinantes da Escola de Data Science, considerando-se o plano \nrenovável de assinatura mensal. \n \n \nHeric Frederic Turmann Saliby - blackbull0075@gmail.com - IP: 191.37.7.13'

# %%
#  Imprimir texto do arquivo PDF
texto = page1.extract_text()
print(texto)
# Out:
# SIGMOIDAL
#
# Relatório Diário
#
# Data: 10/08/2020
#
# RECEITA: R$ 1.397,00
# DADOS ATUALIZADOS POR CARLOS MELO
#
#
#  Visitantes: 1367
# A quantidade de visitantes diz respeito a visitantes únicos visitando qualquer
# página do domínio ou subdomínio sigmoidal.ai. Compreende, então, cursos,
# blogs e landing pages.
#  Inscritos: 33
# É considerado aqui o número de leads gerados por meio de cadastro
# voluntário nos formulários do cabeçalho, rodapé ou materiais ricos (como
# eBook, infográficos, entre outros).
#  Assinantes: 6
# Clientes assinantes da Escola de Data Science, considerando-se o plano
# renovável de assinatura mensal.
#
#
# Heric Frederic Turmann Saliby - blackbull0075@gmail.com - IP: 191.37.7.13

# %%
pdf.metadata
# Out:
# {'AssetID': 'TF10002026',
#  'Author': 'Carlos Melo',
#  'Comments': '',
#  'Company': '',
#  'CreationDate': 'D:20200831180053Z',
#  'Creator': 'Acrobat PDFMaker 20 for Word',
#  'Keywords': 'report, vendas, sigmoidal, diário, relatório',
#  'ModDate': 'D:20210811102911',
#  'Producer': 'HexaPDF version 0.15.7',
#  'SourceModified': 'D:20200831180051',
#  'Subject': 'Template para relatório diário',
#  'Title': 'Relatório Sigmoidal'}
